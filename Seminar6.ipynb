# %% [markdown]
# # Seminar 6

# %% [markdown]
# ## distributia uniforma - varianta 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ```python
# numpy.random.uniform(low, high, size)
# ```

# %%
np.random.uniform()
# Out:
# 0.1804884497116641

# %%
np.random.uniform(1,3)
# Out:
# 1.917726509554085

# %%
np.random.uniform(1,3,5)
# Out:
# array([2.37507545, 2.92890558, 1.1175859 , 1.0053673 , 1.03859645])

# %%
x=np.random.uniform(1,3,10000)

# %%
x.shape
# Out:
# (10000,)

# %%
np.mean(x)
# Out:
# 1.996345220043978

# %%
plt.hist(x, bins=30)
# Out:
# (array([329., 357., 372., 309., 302., 339., 315., 322., 365., 346., 338.,
#         345., 333., 320., 326., 330., 352., 317., 340., 317., 322., 342.,
#         351., 355., 329., 318., 317., 360., 325., 307.]),
#  array([1.00008475, 1.06674607, 1.13340738, 1.2000687 , 1.26673002,
#         1.33339133, 1.40005265, 1.46671397, 1.53337528, 1.6000366 ,
#         1.66669792, 1.73335923, 1.80002055, 1.86668187, 1.93334319,
#         2.0000045 , 2.06666582, 2.13332714, 2.19998845, 2.26664977,
#         2.33331109, 2.3999724 , 2.46663372, 2.53329504, 2.59995635,
#         2.66661767, 2.73327899, 2.7999403 , 2.86660162, 2.93326294,
#         2.99992425]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## distributia uniforma - varianta 2

# %%
from scipy.stats import uniform

# %%
u=uniform()

# %%
u

# %%
u_2_6 = uniform(loc=2, scale=4) # valori intre 2 si 2+4

# %%
u.rvs()
# Out:
# 0.11680010547511377

# %%
u_2_6.rvs()
# Out:
# 3.9983893470138145

# %%
uniform.rvs()
# Out:
# 0.27294192054751076

# %%
uniform.rvs(2,4)
# Out:
# 2.118565882811482

# %%
u.rvs(10)
# Out:
# array([0.38395065, 0.93233516, 0.5704898 , 0.90151922, 0.87376665,
#        0.43364427, 0.09683912, 0.99816725, 0.84421753, 0.43757568])

# %%
x_standard=u.rvs(10000)

# %%
x_2_6=u_2_6.rvs(10000)

# %%
plt.hist(x_standard)
# Out:
# (array([1012., 1019., 1034.,  971., 1043.,  966.,  949.,  977., 1013.,
#         1016.]),
#  array([3.40245186e-05, 1.00016565e-01, 1.99999105e-01, 2.99981645e-01,
#         3.99964186e-01, 4.99946726e-01, 5.99929266e-01, 6.99911806e-01,
#         7.99894347e-01, 8.99876887e-01, 9.99859427e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x_2_6)
# Out:
# (array([1014.,  980.,  984.,  989., 1055.,  984.,  993.,  980., 1007.,
#         1014.]),
#  array([2.00013148, 2.40009044, 2.80004941, 3.20000837, 3.59996733,
#         3.9999263 , 4.39988526, 4.79984423, 5.19980319, 5.59976216,
#         5.99972112]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# $f$ este probability density function (pdf)

# %%
u.pdf(0.2)
# Out:
# 1.0

# %%
u.pdf(-6)
# Out:
# 0.0

# %%
x=np.array([-4,0.1,1,3])
u.pdf(x)
# Out:
# array([0., 1., 1., 0.])

# %%
x=np.linspace(-1,2,100)

# %%
plt.plot(x, u.pdf(x))

# %%
x=np.linspace(0,8,100)
plt.plot(x, u_2_6.pdf(x))

# %% [markdown]
# Functia de repartitie este cumulative distribution function (cdf)

# %%
u.cdf(0.5)
# Out:
# 0.5

# %%
x=np.linspace(-1,2,100)
plt.plot(x, u.cdf(x))

# %%
x=np.linspace(0,8,100)
plt.plot(x, u_2_6.cdf(x))

# %% [markdown]
# inversa cdf: pentru ce valoare a lui $x$ avem o anumita probabilitate la stanga lui $x$?
#
# $P(X\le x)=0.4$, cat e $x$?

# %%
u.ppf(0.4)
# Out:
# 0.4

# %%
u_2_6.ppf(0.4)
# Out:
# 3.6

# %%
u_2_6.cdf(3.6)
# Out:
# 0.4

# %%
u.mean()
# Out:
# 0.5

# %%
u_2_6.mean()
# Out:
# 4.0

# %%
u.median()
# Out:
# 0.5

# %%
u.var()
# Out:
# 0.08333333333333333

# %%
u.std()
# Out:
# 0.28867513459481287

# %% [markdown]
# ## distributia normala

# %%
from scipy.stats import norm

# %%
Z=norm()

# %%
Z.mean()
# Out:
# 0.0

# %%
Z.std()
# Out:
# 1.0

# %%
x=np.linspace(-4,4,100)
plt.plot(x, Z.pdf(x))

# %%
x=np.linspace(-4,4,100)
plt.plot(x, Z.cdf(x))

# %%
Z.cdf(0)
# Out:
# 0.5

# %% [markdown]
# $P(Z<1.3)$

# %%
Z.cdf(1.3)
# Out:
# 0.9031995154143897

# %%
x=np.linspace(-4,4,100)
plt.plot(x, Z.pdf(x))
plt.fill_between(x, Z.pdf(x), where = x<1.3)
plt.title(f'$P(Z< 1.3)=${Z.cdf(1.3)}')
# Out:
# Text(0.5, 1.0, '$P(Z< 1.3)=$0.9031995154143897')

# %% [markdown]
# $P(Z\ge 1.3)$

# %%
1-Z.cdf(1.3)
# Out:
# 0.0968004845856103

# %%
x=np.linspace(-4,4,100)
plt.plot(x, Z.pdf(x))
plt.fill_between(x, Z.pdf(x), where = x>1.3)
plt.title(f'$P(Z< 1.3)=${1-Z.cdf(1.3)}')
# Out:
# Text(0.5, 1.0, '$P(Z< 1.3)=$0.0968004845856103')

# %% [markdown]
# $P(0.2\le Z \le 0.8)$

# %%
Z.cdf(0.8)-Z.cdf(0.2)
# Out:
# 0.20888489197750038

# %%
x=np.linspace(-4,4,100)
plt.plot(x, Z.pdf(x))
plt.fill_between(x, Z.pdf(x), where =np.logical_and( (0.2<x) , (x<0.8)))
plt.title(f'$P(0.2<Z< 0.8)=${Z.cdf(0.8)-Z.cdf(0.2)}')
# Out:
# Text(0.5, 1.0, '$P(0.2<Z< 0.8)=$0.20888489197750038')

# %% [markdown]
# probabilitatea ca Z sa ia valori in afara intervalului [0.2,0.8]

# %%
Z.cdf(0.2) + (1- Z.cdf(0.8))
# Out:
# 0.7911151080224996

# %%
x=np.linspace(-4,4,100)
plt.plot(x, Z.pdf(x))
plt.fill_between(x, Z.pdf(x), where =np.logical_or( (0.2>x) , (x>0.8)))
plt.title(f'$P(Z< 0.2 \cup Z>0.8)=${1-(Z.cdf(0.8)-Z.cdf(0.2))}')
# Out:
# Text(0.5, 1.0, '$P(Z< 0.2 \\cup Z>0.8)=$0.7911151080224996')

# %%
X=norm(loc=3, scale=2)

# %%
X.mean(), X.std()
# Out:
# (3.0, 2.0)

# %%
x=np.linspace(-4, 10, 100)
plt.plot(x,X.pdf(x))

# %%
Z.ppf(0.25)
# Out:
# -0.6744897501960817

# %%
X1=norm(5, 0.1)
X2=norm(5,0.5)
X3=norm(5,1)

# %%
x=np.linspace(3,7, 100)
plt.plot(x,X1.pdf(x), label=f"$\sigma=0.1$")
plt.plot(x,X2.pdf(x), label=f"$\sigma=0.5$")
plt.plot(x,X3.pdf(x), label=f"$\sigma=1$")
plt.legend()
